# %%
import os
os.getcwd()
# Out:
# 'D:\\anaconda\\Jpy Nb\\EDA'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
hab=pd.read_csv("haberman.csv")

# %%
print(hab.shape)
# Out:
# (306, 4)

# %%
hab.ndim
# Out:
# 2

# %%
print(hab.columns)
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
hab["status"].value_counts()
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %%
print(hab.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
# age       306 non-null int64
# year      306 non-null int64
# nodes     306 non-null int64
# status    306 non-null int64
# dtypes: int64(4)
# memory usage: 9.6 KB
# None

# %%
hab.describe()
# Out:
#               age        year       nodes      status
# count  306.000000  306.000000  306.000000  306.000000
# mean    52.457516   62.852941    4.026144    1.264706
# std     10.803452    3.249405    7.189654    0.441899
# min     30.000000   58.000000    0.000000    1.000000
# 25%     44.000000   60.000000    0.000000    1.000000
# 50%     52.000000   63.000000    1.000000    1.000000
# 75%     60.750000   65.750000    4.000000    2.000000
# max     83.000000   69.000000   52.000000    2.000000

# %%
print(list(hab["status"].unique()))
# Out:
# [nan]

# %%
print(hab)
# Out:
#      age  year  nodes status
# 0     30    64      1    NaN
# 1     30    62      3    NaN
# 2     30    65      0    NaN
# 3     31    59      2    NaN
# 4     31    65      4    NaN
# 5     33    58     10    NaN
# 6     33    60      0    NaN
# 7     34    59      0    NaN
# 8     34    66      9    NaN
# 9     34    58     30    NaN
# 10    34    60      1    NaN
# 11    34    61     10    NaN
# 12    34    67      7    NaN
# 13    34    60      0    NaN
# 14    35    64     13    NaN
# 15    35    63      0    NaN
# 16    36    60      1    NaN
# 17    36    69      0    NaN
# 18    37    60      0    NaN
# 19    37    63      0    NaN
# 20    37    58      0    NaN
# 21    37    59      6    NaN
# 22    37    60     15    NaN
# 23    37    63      0    NaN
# 24    38    69     21    NaN
# 25    38    59      2    NaN
# 26    38    60      0    NaN
# 27    38    60      0    NaN
# 28    38    62      3    NaN
# 29    38    64      1    NaN
# ..   ...   ...    ...    ...
# ...

# %%
hab
# Out:
#      age  year  nodes status
# 0     30    64      1    NaN
# 1     30    62      3    NaN
# 2     30    65      0    NaN
# 3     31    59      2    NaN
# 4     31    65      4    NaN
# 5     33    58     10    NaN
# 6     33    60      0    NaN
# 7     34    59      0    NaN
# 8     34    66      9    NaN
# 9     34    58     30    NaN
# 10    34    60      1    NaN
# 11    34    61     10    NaN
# 12    34    67      7    NaN
# 13    34    60      0    NaN
# 14    35    64     13    NaN
# 15    35    63      0    NaN
# 16    36    60      1    NaN
# 17    36    69      0    NaN
# 18    37    60      0    NaN
# 19    37    63      0    NaN
# 20    37    58      0    NaN
# 21    37    59      6    NaN
# 22    37    60     15    NaN
# 23    37    63      0    NaN
# 24    38    69     21    NaN
# 25    38    59      2    NaN
# 26    38    60      0    NaN
# 27    38    60      0    NaN
# 28    38    62      3    NaN
# 29    38    64      1    NaN
# ..   ...   ...    ...    ...
# ...

# %%
hab.plot(kind='scatter', x='age', y='year') ;
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(hab, size=4) \
   .map(plt.scatter, "age", "year") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Rohit\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#cannot distinguish bet age and year

# %%
hab.plot(kind='scatter', x='age', y='status') ;
plt.show()

# %%
hab
# Out:
#      age  year  nodes status
# 0     30    64      1    NaN
# 1     30    62      3    NaN
# 2     30    65      0    NaN
# 3     31    59      2    NaN
# 4     31    65      4    NaN
# 5     33    58     10    NaN
# 6     33    60      0    NaN
# 7     34    59      0    NaN
# 8     34    66      9    NaN
# 9     34    58     30    NaN
# 10    34    60      1    NaN
# 11    34    61     10    NaN
# 12    34    67      7    NaN
# 13    34    60      0    NaN
# 14    35    64     13    NaN
# 15    35    63      0    NaN
# 16    36    60      1    NaN
# 17    36    69      0    NaN
# 18    37    60      0    NaN
# 19    37    63      0    NaN
# 20    37    58      0    NaN
# 21    37    59      6    NaN
# 22    37    60     15    NaN
# 23    37    63      0    NaN
# 24    38    69     21    NaN
# 25    38    59      2    NaN
# 26    38    60      0    NaN
# 27    38    60      0    NaN
# 28    38    62      3    NaN
# 29    38    64      1    NaN
# ..   ...   ...    ...    ...
# ...

# %%
hab=pd.read_csv("haberman.csv")

# %%
hab
# Out:
#      age  year  nodes  status
# 0     30    64      1       1
# 1     30    62      3       1
# 2     30    65      0       1
# 3     31    59      2       1
# 4     31    65      4       1
# 5     33    58     10       1
# 6     33    60      0       1
# 7     34    59      0       2
# 8     34    66      9       2
# 9     34    58     30       1
# 10    34    60      1       1
# 11    34    61     10       1
# 12    34    67      7       1
# 13    34    60      0       1
# 14    35    64     13       1
# 15    35    63      0       1
# 16    36    60      1       1
# 17    36    69      0       1
# 18    37    60      0       1
# 19    37    63      0       1
# 20    37    58      0       1
# 21    37    59      6       1
# 22    37    60     15       1
# 23    37    63      0       1
# 24    38    69     21       2
# 25    38    59      2       1
# 26    38    60      0       1
# 27    38    60      0       1
# 28    38    62      3       1
# 29    38    64      1       1
# ...

# %%
hab.plot(kind='scatter', x='age', y='status') ;
plt.show()

# %%
sns.set_style("whitegrid");
sns.pairplot(hab, hue="age", size=5);
plt.show()
# Out:
# C:\Users\Rohit\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
hab.plot(kind='scatter', x='nodes', y='status') ;
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(hab, hue="status", size=4) \
   .map(plt.scatter, "nodes", "status") \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(hab, hue="status", size=6) \
   .map(sns.distplot, "nodes") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Rohit\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# we ac say here the patients who ahave  nodes bet 0 to 5 having  chances to survive with mean 0.3

# %%
sns.FacetGrid(hab, hue="status", size=6) \
   .map(sns.distplot, "year") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Rohit\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(hab, hue="status", size=6) \
   .map(sns.distplot, "age") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Rohit\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(hab, hue="nodes", size=5) \
   .map(sns.distplot, "year") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Rohit\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
hab.plot(kind='scatter', x='year', y='status') ;
plt.show()

# %%
hab.plot(kind='scatter', x='nodes', y='year') ;
plt.show()

# %%
# nodes bet 0 to 5 at any year are dense

# %%
sns.set_style("whitegrid");
sns.FacetGrid(hab, hue="nodes", size=4) \
   .map(plt.scatter, "nodes", "status") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Rohit\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x='status',y='nodes', data=hab)
plt.show()

# %%
sns.boxplot(x='status',y='year', data=hab)
plt.show()

# %%
sns.boxplot(x='status',y='age', data=hab)
plt.show()

# %%
sns.jointplot(x="status", y="nodes", data=hab, kind="kde");
plt.show();
